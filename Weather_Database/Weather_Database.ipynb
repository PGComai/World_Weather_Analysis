# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count
len(cities)
# Out:
# 755

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_desc = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')     

        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Current Description": city_weather_desc,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | bambous virieux
# Processing Record 2 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 3 of Set 1 | karratha
# Processing Record 4 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 5 of Set 1 | ponta do sol
# Processing Record 6 of Set 1 | taoudenni
# Processing Record 7 of Set 1 | pisco
# Processing Record 8 of Set 1 | mar del plata
# Processing Record 9 of Set 1 | graham
# Processing Record 10 of Set 1 | repnoye
# Processing Record 11 of Set 1 | nizwa
# Processing Record 12 of Set 1 | punta arenas
# Processing Record 13 of Set 1 | bluff
# Processing Record 14 of Set 1 | puerto ayora
# Processing Record 15 of Set 1 | chokurdakh
# Processing Record 16 of Set 1 | east london
# Processing Record 17 of Set 1 | rikitea
# Processing Record 18 of Set 1 | ketchikan
# Processing Record 19 of Set 1 | albany
# Processing Record 20 of Set 1 | hobart
# Processing Record 21 of Set 1 | nanortalik
# Processing Record 22 of Set 1 | qaanaaq
# Processing Record 23 of Set 1 | caravelas
# Processing Record 24 of Set 1 | bonavista
# Processing Record 25 of Set 1 | le port
# Processing Record 26 of Set 1 | tasiilaq
# Processing Record 27 of Set 1 | toliary
# City not found. Skipping...
# Processing Record 28 of Set 1 | warqla
# City not found. Skipping...
# Processing Record 29 of Set 1 | smithers
# Processing Record 30 of Set 1 | ilulissat
# Processing Record 31 of Set 1 | neiafu
# Processing Record 32 of Set 1 | ribeira grande
# Processing Record 33 of Set 1 | berbera
# Processing Record 34 of Set 1 | sistranda
# Processing Record 35 of Set 1 | hermanus
# Processing Record 36 of Set 1 | ostrovnoy
# Processing Record 37 of Set 1 | tiksi
# Processing Record 38 of Set 1 | de-kastri
# Processing Record 39 of Set 1 | busselton
# Processing Record 40 of Set 1 | porto torres
# Processing Record 41 of Set 1 | sitka
# Processing Record 42 of Set 1 | myitkyina
# Processing Record 43 of Set 1 | new norfolk
# Processing Record 44 of Set 1 | jiwani
# Processing Record 45 of Set 1 | thompson
# Processing Record 46 of Set 1 | valdivia
# Processing Record 47 of Set 1 | castro
# Processing Record 48 of Set 1 | iqaluit
# Processing Record 49 of Set 1 | jamestown
# Processing Record 50 of Set 1 | tomatlan
# Processing Record 1 of Set 2 | hambantota
# Processing Record 2 of Set 2 | todos santos
# Processing Record 3 of Set 2 | balkanabat
# Processing Record 4 of Set 2 | hami
# Processing Record 5 of Set 2 | cidreira
# Processing Record 6 of Set 2 | saldanha
# Processing Record 7 of Set 2 | ushuaia
# Processing Record 8 of Set 2 | talnakh
# Processing Record 9 of Set 2 | sao joao da barra
# Processing Record 10 of Set 2 | yellowknife
# Processing Record 11 of Set 2 | hilo
# Processing Record 12 of Set 2 | tuktoyaktuk
# Processing Record 13 of Set 2 | nguiu
# City not found. Skipping...
# Processing Record 14 of Set 2 | torbay
# Processing Record 15 of Set 2 | nikolskoye
# Processing Record 16 of Set 2 | bilibino
# Processing Record 17 of Set 2 | hervey bay
# Processing Record 18 of Set 2 | cherskiy
# Processing Record 19 of Set 2 | carnarvon
# Processing Record 20 of Set 2 | mount isa
# Processing Record 21 of Set 2 | cape town
# Processing Record 22 of Set 2 | lebu
# Processing Record 23 of Set 2 | arraial do cabo
# Processing Record 24 of Set 2 | college
# Processing Record 25 of Set 2 | oriximina
# Processing Record 26 of Set 2 | victoria
# Processing Record 27 of Set 2 | fortuna
# Processing Record 28 of Set 2 | simbahan
# Processing Record 29 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 30 of Set 2 | avarua
# Processing Record 31 of Set 2 | jales
# Processing Record 32 of Set 2 | atuona
# Processing Record 33 of Set 2 | cairns
# Processing Record 34 of Set 2 | lompoc
# Processing Record 35 of Set 2 | mataura
# Processing Record 36 of Set 2 | cambara
# Processing Record 37 of Set 2 | leningradskiy
# Processing Record 38 of Set 2 | stokmarknes
# Processing Record 39 of Set 2 | mahebourg
# Processing Record 40 of Set 2 | canoinhas
# Processing Record 41 of Set 2 | saint-augustin
# Processing Record 42 of Set 2 | vaini
# Processing Record 43 of Set 2 | pecos
# Processing Record 44 of Set 2 | alvorada
# Processing Record 45 of Set 2 | narasannapeta
# Processing Record 46 of Set 2 | tuatapere
# Processing Record 47 of Set 2 | marawi
# Processing Record 48 of Set 2 | bredasdorp
# Processing Record 49 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 50 of Set 2 | pangnirtung
# Processing Record 1 of Set 3 | naze
# Processing Record 2 of Set 3 | kushiro
# Processing Record 3 of Set 3 | klaksvik
# Processing Record 4 of Set 3 | upernavik
# Processing Record 5 of Set 3 | presevo
# Processing Record 6 of Set 3 | mushie
# Processing Record 7 of Set 3 | presidente epitacio
# Processing Record 8 of Set 3 | tawzar
# City not found. Skipping...
# Processing Record 9 of Set 3 | benguela
# Processing Record 10 of Set 3 | severo-kurilsk
# Processing Record 11 of Set 3 | touros
# Processing Record 12 of Set 3 | dongsheng
# Processing Record 13 of Set 3 | banikoara
# Processing Record 14 of Set 3 | bethel
# Processing Record 15 of Set 3 | port alfred
# Processing Record 16 of Set 3 | ola
# Processing Record 17 of Set 3 | praia
# Processing Record 18 of Set 3 | marquette
# Processing Record 19 of Set 3 | tokur
# Processing Record 20 of Set 3 | souillac
# Processing Record 21 of Set 3 | georgetown
# Processing Record 22 of Set 3 | norman wells
# Processing Record 23 of Set 3 | warri
# Processing Record 24 of Set 3 | sungai siput utara
# City not found. Skipping...
# Processing Record 25 of Set 3 | acapulco
# Processing Record 26 of Set 3 | oeiras
# Processing Record 27 of Set 3 | mattru
# Processing Record 28 of Set 3 | meadow lake
# Processing Record 29 of Set 3 | novopavlovsk
# Processing Record 30 of Set 3 | kapaa
# Processing Record 31 of Set 3 | mishan
# Processing Record 32 of Set 3 | pilar
# Processing Record 33 of Set 3 | longyearbyen
# Processing Record 34 of Set 3 | jalu
# Processing Record 35 of Set 3 | antsohihy
# Processing Record 36 of Set 3 | vila
# Processing Record 37 of Set 3 | nishihara
# Processing Record 38 of Set 3 | rocha
# Processing Record 39 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 40 of Set 3 | ormara
# Processing Record 41 of Set 3 | airai
# Processing Record 42 of Set 3 | tarudant
# City not found. Skipping...
# Processing Record 43 of Set 3 | san quintin
# Processing Record 44 of Set 3 | kargat
# Processing Record 45 of Set 3 | yago
# Processing Record 46 of Set 3 | sao filipe
# Processing Record 47 of Set 3 | znamenskoye
# Processing Record 48 of Set 3 | hithadhoo
# Processing Record 49 of Set 3 | buraydah
# Processing Record 50 of Set 3 | khatanga
# Processing Record 1 of Set 4 | narsaq
# Processing Record 2 of Set 4 | loukhi
# Processing Record 3 of Set 4 | san andres
# Processing Record 4 of Set 4 | namibe
# Processing Record 5 of Set 4 | esperance
# Processing Record 6 of Set 4 | hauterive
# Processing Record 7 of Set 4 | vostok
# Processing Record 8 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 9 of Set 4 | hua hin
# Processing Record 10 of Set 4 | paamiut
# Processing Record 11 of Set 4 | tahta
# Processing Record 12 of Set 4 | plouzane
# Processing Record 13 of Set 4 | buala
# Processing Record 14 of Set 4 | shingu
# Processing Record 15 of Set 4 | riyadh
# Processing Record 16 of Set 4 | dhangadhi
# Processing Record 17 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 18 of Set 4 | sao felix do xingu
# Processing Record 19 of Set 4 | saskylakh
# Processing Record 20 of Set 4 | santa cruz
# Processing Record 21 of Set 4 | butaritari
# Processing Record 22 of Set 4 | evensk
# Processing Record 23 of Set 4 | rawannawi
# City not found. Skipping...
# Processing Record 24 of Set 4 | kaitangata
# Processing Record 25 of Set 4 | kyabe
# Processing Record 26 of Set 4 | adrar
# Processing Record 27 of Set 4 | karaul
# City not found. Skipping...
# Processing Record 28 of Set 4 | umm lajj
# Processing Record 29 of Set 4 | flinders
# Processing Record 30 of Set 4 | havoysund
# Processing Record 31 of Set 4 | yomitan
# City not found. Skipping...
# Processing Record 32 of Set 4 | sataua
# City not found. Skipping...
# Processing Record 33 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 34 of Set 4 | axim
# Processing Record 35 of Set 4 | lata
# Processing Record 36 of Set 4 | katsuura
# Processing Record 37 of Set 4 | rantepao
# Processing Record 38 of Set 4 | dunedin
# Processing Record 39 of Set 4 | niquelandia
# Processing Record 40 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 41 of Set 4 | lodwar
# Processing Record 42 of Set 4 | emporia
# Processing Record 43 of Set 4 | bocaiuva
# Processing Record 44 of Set 4 | aripuana
# Processing Record 45 of Set 4 | abonnema
# Processing Record 46 of Set 4 | aquiraz
# Processing Record 47 of Set 4 | cockburn harbour
# City not found. Skipping...
# Processing Record 48 of Set 4 | aranos
# Processing Record 49 of Set 4 | goroka
# Processing Record 50 of Set 4 | shubarshi
# Processing Record 1 of Set 5 | jatai
# Processing Record 2 of Set 5 | severo-yeniseyskiy
# Processing Record 3 of Set 5 | tessalit
# Processing Record 4 of Set 5 | provideniya
# Processing Record 5 of Set 5 | hamilton
# Processing Record 6 of Set 5 | oyem
# Processing Record 7 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 8 of Set 5 | berlevag
# Processing Record 9 of Set 5 | mareeba
# Processing Record 10 of Set 5 | kosh-agach
# Processing Record 11 of Set 5 | ambon
# Processing Record 12 of Set 5 | codrington
# Processing Record 13 of Set 5 | boende
# Processing Record 14 of Set 5 | petropavlovsk-kamchatskiy
# Processing Record 15 of Set 5 | cosmesti
# Processing Record 16 of Set 5 | kyren
# Processing Record 17 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 18 of Set 5 | amapa
# Processing Record 19 of Set 5 | tongliao
# Processing Record 20 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 21 of Set 5 | muros
# Processing Record 22 of Set 5 | chuy
# Processing Record 23 of Set 5 | dikson
# Processing Record 24 of Set 5 | barrow
# Processing Record 25 of Set 5 | wulanhaote
# City not found. Skipping...
# Processing Record 26 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 27 of Set 5 | manica
# Processing Record 28 of Set 5 | quatre cocos
# Processing Record 29 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 30 of Set 5 | pevek
# Processing Record 31 of Set 5 | iskateley
# Processing Record 32 of Set 5 | najran
# Processing Record 33 of Set 5 | port macquarie
# Processing Record 34 of Set 5 | manaure
# Processing Record 35 of Set 5 | horasan
# Processing Record 36 of Set 5 | gazanjyk
# Processing Record 37 of Set 5 | oistins
# Processing Record 38 of Set 5 | cayenne
# Processing Record 39 of Set 5 | marsabit
# Processing Record 40 of Set 5 | alexandria
# Processing Record 41 of Set 5 | ipora
# Processing Record 42 of Set 5 | bilma
# Processing Record 43 of Set 5 | port lincoln
# Processing Record 44 of Set 5 | zhigansk
# Processing Record 45 of Set 5 | sao miguel do araguaia
# Processing Record 46 of Set 5 | port elizabeth
# Processing Record 47 of Set 5 | moranbah
# Processing Record 48 of Set 5 | aykhal
# Processing Record 49 of Set 5 | loandjili
# Processing Record 50 of Set 5 | vestmannaeyjar
# Processing Record 1 of Set 6 | castro-urdiales
# Processing Record 2 of Set 6 | lavrentiya
# Processing Record 3 of Set 6 | payson
# Processing Record 4 of Set 6 | miedzyrzec podlaski
# Processing Record 5 of Set 6 | eyl
# Processing Record 6 of Set 6 | mountain home
# Processing Record 7 of Set 6 | kuhestan
# City not found. Skipping...
# Processing Record 8 of Set 6 | were ilu
# Processing Record 9 of Set 6 | kolokani
# Processing Record 10 of Set 6 | magole
# Processing Record 11 of Set 6 | warrnambool
# Processing Record 12 of Set 6 | barranca
# Processing Record 13 of Set 6 | taltal
# Processing Record 14 of Set 6 | derzhavinsk
# Processing Record 15 of Set 6 | gejiu
# Processing Record 16 of Set 6 | takhtamygda
# Processing Record 17 of Set 6 | marsh harbour
# Processing Record 18 of Set 6 | black river
# Processing Record 19 of Set 6 | grand gaube
# Processing Record 20 of Set 6 | atasu
# Processing Record 21 of Set 6 | guayaramerin
# Processing Record 22 of Set 6 | fort nelson
# Processing Record 23 of Set 6 | wilmington
# Processing Record 24 of Set 6 | faanui
# Processing Record 25 of Set 6 | zaozerne
# Processing Record 26 of Set 6 | xining
# Processing Record 27 of Set 6 | marzuq
# Processing Record 28 of Set 6 | leh
# Processing Record 29 of Set 6 | jujuy
# City not found. Skipping...
# Processing Record 30 of Set 6 | el dorado
# Processing Record 31 of Set 6 | kavieng
# Processing Record 32 of Set 6 | louisbourg
# City not found. Skipping...
# Processing Record 33 of Set 6 | lagoa
# Processing Record 34 of Set 6 | san javier
# Processing Record 35 of Set 6 | mirnyy
# Processing Record 36 of Set 6 | limbang
# Processing Record 37 of Set 6 | merauke
# Processing Record 38 of Set 6 | manokwari
# Processing Record 39 of Set 6 | ensley
# Processing Record 40 of Set 6 | komsomolskiy
# Processing Record 41 of Set 6 | vuktyl
# Processing Record 42 of Set 6 | karamay
# City not found. Skipping...
# Processing Record 43 of Set 6 | la palma
# Processing Record 44 of Set 6 | laguna
# Processing Record 45 of Set 6 | kamenskoye
# City not found. Skipping...
# Processing Record 46 of Set 6 | elizabeth city
# Processing Record 47 of Set 6 | comodoro rivadavia
# Processing Record 48 of Set 6 | santo antonio do sudoeste
# Processing Record 49 of Set 6 | bousso
# Processing Record 50 of Set 6 | tehachapi
# Processing Record 1 of Set 7 | carberry
# Processing Record 2 of Set 7 | lyngseidet
# Processing Record 3 of Set 7 | tevaitoa
# Processing Record 4 of Set 7 | vardo
# Processing Record 5 of Set 7 | kpandae
# Processing Record 6 of Set 7 | angoche
# Processing Record 7 of Set 7 | nanfeng
# Processing Record 8 of Set 7 | asau
# Processing Record 9 of Set 7 | aflu
# City not found. Skipping...
# Processing Record 10 of Set 7 | kulhudhuffushi
# Processing Record 11 of Set 7 | suez
# Processing Record 12 of Set 7 | the valley
# Processing Record 13 of Set 7 | mount gambier
# Processing Record 14 of Set 7 | kristinehamn
# Processing Record 15 of Set 7 | hunza
# City not found. Skipping...
# Processing Record 16 of Set 7 | shaunavon
# Processing Record 17 of Set 7 | kastamonu
# Processing Record 18 of Set 7 | smoky lake
# Processing Record 19 of Set 7 | shaowu
# Processing Record 20 of Set 7 | abbeville
# Processing Record 21 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 22 of Set 7 | saint george
# Processing Record 23 of Set 7 | bengkulu
# Processing Record 24 of Set 7 | bokoro
# Processing Record 25 of Set 7 | camacha
# Processing Record 26 of Set 7 | kuvshinovo
# Processing Record 27 of Set 7 | pasni
# Processing Record 28 of Set 7 | sola
# Processing Record 29 of Set 7 | salta
# Processing Record 30 of Set 7 | jiaojiang
# Processing Record 31 of Set 7 | borogontsy
# Processing Record 32 of Set 7 | toora-khem
# Processing Record 33 of Set 7 | myaundzha
# Processing Record 34 of Set 7 | krasnozerskoye
# Processing Record 35 of Set 7 | saint-pierre
# Processing Record 36 of Set 7 | alugan
# Processing Record 37 of Set 7 | oussouye
# Processing Record 38 of Set 7 | cap malheureux
# Processing Record 39 of Set 7 | wattegama
# Processing Record 40 of Set 7 | kovdor
# Processing Record 41 of Set 7 | ouesso
# Processing Record 42 of Set 7 | yakeshi
# Processing Record 43 of Set 7 | broome
# Processing Record 44 of Set 7 | sarrebourg
# Processing Record 45 of Set 7 | omboue
# Processing Record 46 of Set 7 | nisia floresta
# Processing Record 47 of Set 7 | grindavik
# Processing Record 48 of Set 7 | general roca
# Processing Record 49 of Set 7 | sabang
# Processing Record 50 of Set 7 | paulista
# Processing Record 1 of Set 8 | pushkinskiye gory
# Processing Record 2 of Set 8 | boguchany
# Processing Record 3 of Set 8 | luanda
# Processing Record 4 of Set 8 | chapais
# Processing Record 5 of Set 8 | gigmoto
# Processing Record 6 of Set 8 | bloemfontein
# Processing Record 7 of Set 8 | igrim
# Processing Record 8 of Set 8 | setermoen
# Processing Record 9 of Set 8 | noshiro
# Processing Record 10 of Set 8 | kodiak
# Processing Record 11 of Set 8 | qarayeri
# Processing Record 12 of Set 8 | robertsport
# Processing Record 13 of Set 8 | graikokhorion
# City not found. Skipping...
# Processing Record 14 of Set 8 | half moon bay
# Processing Record 15 of Set 8 | pitimbu
# Processing Record 16 of Set 8 | northam
# Processing Record 17 of Set 8 | casablanca
# Processing Record 18 of Set 8 | sept-iles
# Processing Record 19 of Set 8 | margate
# Processing Record 20 of Set 8 | vallenar
# Processing Record 21 of Set 8 | murray bridge
# Processing Record 22 of Set 8 | kununurra
# Processing Record 23 of Set 8 | helmsdale
# Processing Record 24 of Set 8 | adeje
# Processing Record 25 of Set 8 | porterville
# Processing Record 26 of Set 8 | moerai
# Processing Record 27 of Set 8 | dolbeau
# City not found. Skipping...
# Processing Record 28 of Set 8 | binangonan
# Processing Record 29 of Set 8 | sibolga
# Processing Record 30 of Set 8 | meulaboh
# Processing Record 31 of Set 8 | tornio
# Processing Record 32 of Set 8 | lima
# Processing Record 33 of Set 8 | kushima
# Processing Record 34 of Set 8 | rio grande
# Processing Record 35 of Set 8 | bathurst
# Processing Record 36 of Set 8 | vadakku valliyur
# Processing Record 37 of Set 8 | visby
# Processing Record 38 of Set 8 | havelock
# Processing Record 39 of Set 8 | harper
# Processing Record 40 of Set 8 | ejido
# Processing Record 41 of Set 8 | tabiauea
# City not found. Skipping...
# Processing Record 42 of Set 8 | camana
# Processing Record 43 of Set 8 | schwedt
# Processing Record 44 of Set 8 | eureka
# Processing Record 45 of Set 8 | dalbandin
# Processing Record 46 of Set 8 | namwala
# Processing Record 47 of Set 8 | longjiang
# Processing Record 48 of Set 8 | san cristobal
# Processing Record 49 of Set 8 | ascension
# Processing Record 50 of Set 8 | coruripe
# Processing Record 1 of Set 9 | geraldton
# Processing Record 2 of Set 9 | nome
# Processing Record 3 of Set 9 | pangody
# Processing Record 4 of Set 9 | palana
# Processing Record 5 of Set 9 | alofi
# Processing Record 6 of Set 9 | egvekinot
# Processing Record 7 of Set 9 | sann
# Processing Record 8 of Set 9 | chesterton
# Processing Record 9 of Set 9 | venado tuerto
# Processing Record 10 of Set 9 | russell
# Processing Record 11 of Set 9 | mapiripan
# Processing Record 12 of Set 9 | banepa
# Processing Record 13 of Set 9 | waddan
# Processing Record 14 of Set 9 | emerald
# Processing Record 15 of Set 9 | nokaneng
# Processing Record 16 of Set 9 | keelung
# Processing Record 17 of Set 9 | orlik
# Processing Record 18 of Set 9 | vysokogornyy
# Processing Record 19 of Set 9 | anadyr
# Processing Record 20 of Set 9 | bireun
# Processing Record 21 of Set 9 | kalanguy
# Processing Record 22 of Set 9 | barcelos
# Processing Record 23 of Set 9 | okakarara
# Processing Record 24 of Set 9 | cockburn town
# Processing Record 25 of Set 9 | nedjo
# Processing Record 26 of Set 9 | portland
# Processing Record 27 of Set 9 | canatlan
# Processing Record 28 of Set 9 | tura
# Processing Record 29 of Set 9 | chifeng
# Processing Record 30 of Set 9 | dawlatabad
# Processing Record 31 of Set 9 | chikoy
# City not found. Skipping...
# Processing Record 32 of Set 9 | san rafael del sur
# Processing Record 33 of Set 9 | arman
# Processing Record 34 of Set 9 | nouadhibou
# Processing Record 35 of Set 9 | weligama
# Processing Record 36 of Set 9 | beringovskiy
# Processing Record 37 of Set 9 | borova
# Processing Record 38 of Set 9 | santona
# Processing Record 39 of Set 9 | luwingu
# Processing Record 40 of Set 9 | sorong
# Processing Record 41 of Set 9 | troitskoye
# Processing Record 42 of Set 9 | luderitz
# Processing Record 43 of Set 9 | saint-denis
# Processing Record 44 of Set 9 | saint-paul
# Processing Record 45 of Set 9 | naryan-mar
# Processing Record 46 of Set 9 | baherden
# Processing Record 47 of Set 9 | tres picos
# Processing Record 48 of Set 9 | bajil
# Processing Record 49 of Set 9 | chicama
# Processing Record 50 of Set 9 | guerrero negro
# Processing Record 1 of Set 10 | vieques
# Processing Record 2 of Set 10 | kavaratti
# Processing Record 3 of Set 10 | borisoglebsk
# Processing Record 4 of Set 10 | ulverstone
# Processing Record 5 of Set 10 | vila velha
# Processing Record 6 of Set 10 | nhulunbuy
# Processing Record 7 of Set 10 | alekseyevsk
# Processing Record 8 of Set 10 | coquimbo
# Processing Record 9 of Set 10 | avera
# Processing Record 10 of Set 10 | ugoofaaru
# Processing Record 11 of Set 10 | hirara
# Processing Record 12 of Set 10 | marcona
# City not found. Skipping...
# Processing Record 13 of Set 10 | ahipara
# Processing Record 14 of Set 10 | pinawa
# Processing Record 15 of Set 10 | moose factory
# Processing Record 16 of Set 10 | padang
# Processing Record 17 of Set 10 | hachinohe
# Processing Record 18 of Set 10 | rawson
# Processing Record 19 of Set 10 | chibombo
# Processing Record 20 of Set 10 | khasan
# Processing Record 21 of Set 10 | namatanai
# Processing Record 22 of Set 10 | saint-philippe
# Processing Record 23 of Set 10 | gimli
# Processing Record 24 of Set 10 | mao
# Processing Record 25 of Set 10 | misratah
# Processing Record 26 of Set 10 | duz
# City not found. Skipping...
# Processing Record 27 of Set 10 | mocambique
# City not found. Skipping...
# Processing Record 28 of Set 10 | vestmanna
# Processing Record 29 of Set 10 | karakulino
# Processing Record 30 of Set 10 | yar-sale
# Processing Record 31 of Set 10 | hanna
# Processing Record 32 of Set 10 | cumaribo
# City not found. Skipping...
# Processing Record 33 of Set 10 | henties bay
# Processing Record 34 of Set 10 | dolinsk
# Processing Record 35 of Set 10 | constitucion
# Processing Record 36 of Set 10 | aljezur
# Processing Record 37 of Set 10 | malakal
# Processing Record 38 of Set 10 | krasnyy oktyabr
# Processing Record 39 of Set 10 | knysna
# Processing Record 40 of Set 10 | la ronge
# Processing Record 41 of Set 10 | pamekasan
# Processing Record 42 of Set 10 | inirida
# Processing Record 43 of Set 10 | saryshagan
# City not found. Skipping...
# Processing Record 44 of Set 10 | imbituba
# Processing Record 45 of Set 10 | sao jose da coroa grande
# Processing Record 46 of Set 10 | baiyin
# Processing Record 47 of Set 10 | kisesa
# Processing Record 48 of Set 10 | payo
# Processing Record 49 of Set 10 | taber
# Processing Record 50 of Set 10 | mpika
# Processing Record 1 of Set 11 | caborca
# Processing Record 2 of Set 11 | shepsi
# Processing Record 3 of Set 11 | kendari
# Processing Record 4 of Set 11 | pulaski
# Processing Record 5 of Set 11 | sosnovo-ozerskoye
# Processing Record 6 of Set 11 | solnechnyy
# Processing Record 7 of Set 11 | sinazongwe
# Processing Record 8 of Set 11 | hauknes
# Processing Record 9 of Set 11 | temaraia
# City not found. Skipping...
# Processing Record 10 of Set 11 | kruisfontein
# Processing Record 11 of Set 11 | launceston
# Processing Record 12 of Set 11 | kovvur
# Processing Record 13 of Set 11 | sommerda
# Processing Record 14 of Set 11 | kahului
# Processing Record 15 of Set 11 | wanning
# Processing Record 16 of Set 11 | marrakesh
# Processing Record 17 of Set 11 | kirkwall
# Processing Record 18 of Set 11 | dubbo
# Processing Record 19 of Set 11 | sterling
# Processing Record 20 of Set 11 | opuwo
# Processing Record 21 of Set 11 | olafsvik
# Processing Record 22 of Set 11 | salalah
# Processing Record 23 of Set 11 | kerki
# City not found. Skipping...
# Processing Record 24 of Set 11 | baruun-urt
# Processing Record 25 of Set 11 | kurilsk
# Processing Record 26 of Set 11 | canico
# Processing Record 27 of Set 11 | hasaki
# Processing Record 28 of Set 11 | ancud
# Processing Record 29 of Set 11 | batsfjord
# Processing Record 30 of Set 11 | alotau
# City not found. Skipping...
# Processing Record 31 of Set 11 | los llanos de aridane
# Processing Record 32 of Set 11 | kholtoson
# Processing Record 33 of Set 11 | usinsk
# Processing Record 34 of Set 11 | tuggurt
# City not found. Skipping...
# Processing Record 35 of Set 11 | mitchell
# Processing Record 36 of Set 11 | talcahuano
# Processing Record 37 of Set 11 | liuhe
# Processing Record 38 of Set 11 | zaysan
# Processing Record 39 of Set 11 | santiago
# Processing Record 40 of Set 11 | daru
# Processing Record 41 of Set 11 | chitral
# Processing Record 42 of Set 11 | segezha
# Processing Record 43 of Set 11 | lazarev
# Processing Record 44 of Set 11 | lakes entrance
# Processing Record 45 of Set 11 | staryy nadym
# Processing Record 46 of Set 11 | lyuban
# Processing Record 47 of Set 11 | barra patuca
# Processing Record 48 of Set 11 | port hedland
# Processing Record 49 of Set 11 | burica
# City not found. Skipping...
# Processing Record 50 of Set 11 | ouadda
# Processing Record 1 of Set 12 | hangu
# Processing Record 2 of Set 12 | anzio
# Processing Record 3 of Set 12 | lasa
# Processing Record 4 of Set 12 | richards bay
# Processing Record 5 of Set 12 | gat
# Processing Record 6 of Set 12 | alihe
# Processing Record 7 of Set 12 | lafia
# Processing Record 8 of Set 12 | aksum
# Processing Record 9 of Set 12 | bend
# Processing Record 10 of Set 12 | kenai
# Processing Record 11 of Set 12 | jesup
# Processing Record 12 of Set 12 | norrtalje
# Processing Record 13 of Set 12 | abalak
# Processing Record 14 of Set 12 | hobyo
# Processing Record 15 of Set 12 | nisporeni
# Processing Record 16 of Set 12 | washougal
# Processing Record 17 of Set 12 | saint combs
# City not found. Skipping...
# Processing Record 18 of Set 12 | khandbari
# Processing Record 19 of Set 12 | sorland
# Processing Record 20 of Set 12 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 21 of Set 12 | san ramon
# Processing Record 22 of Set 12 | zverinogolovskoye
# Processing Record 23 of Set 12 | loa janan
# Processing Record 24 of Set 12 | key west
# Processing Record 25 of Set 12 | gilazi
# City not found. Skipping...
# Processing Record 26 of Set 12 | torquay
# Processing Record 27 of Set 12 | conceicao do araguaia
# Processing Record 28 of Set 12 | pochutla
# Processing Record 29 of Set 12 | mogadishu
# Processing Record 30 of Set 12 | udayagiri
# Processing Record 31 of Set 12 | san rafael
# Processing Record 32 of Set 12 | te anau
# Processing Record 33 of Set 12 | yanam
# Processing Record 34 of Set 12 | kunda
# Processing Record 35 of Set 12 | pokrovsk
# Processing Record 36 of Set 12 | zhezkazgan
# Processing Record 37 of Set 12 | jomalig
# City not found. Skipping...
# Processing Record 38 of Set 12 | cartagena
# Processing Record 39 of Set 12 | banda aceh
# Processing Record 40 of Set 12 | alice springs
# Processing Record 41 of Set 12 | acarau
# Processing Record 42 of Set 12 | takapau
# Processing Record 43 of Set 12 | orikum
# Processing Record 44 of Set 12 | bria
# Processing Record 45 of Set 12 | providencia
# Processing Record 46 of Set 12 | svetlogorsk
# Processing Record 47 of Set 12 | hun
# Processing Record 48 of Set 12 | pascagoula
# Processing Record 49 of Set 12 | kirkuk
# Processing Record 50 of Set 12 | san policarpo
# Processing Record 1 of Set 13 | mersing
# Processing Record 2 of Set 13 | dombarovskiy
# Processing Record 3 of Set 13 | almaznyy
# Processing Record 4 of Set 13 | samarai
# Processing Record 5 of Set 13 | makushino
# Processing Record 6 of Set 13 | nizhniy kuranakh
# Processing Record 7 of Set 13 | anchorage
# Processing Record 8 of Set 13 | storsteinnes
# Processing Record 9 of Set 13 | port augusta
# Processing Record 10 of Set 13 | verkhnyaya inta
# Processing Record 11 of Set 13 | kollegal
# Processing Record 12 of Set 13 | abu samrah
# Processing Record 13 of Set 13 | urucara
# Processing Record 14 of Set 13 | miramar
# Processing Record 15 of Set 13 | katherine
# Processing Record 16 of Set 13 | clyde river
# Processing Record 17 of Set 13 | cabo san lucas
# Processing Record 18 of Set 13 | colborne
# Processing Record 19 of Set 13 | alta floresta
# Processing Record 20 of Set 13 | bolu
# Processing Record 21 of Set 13 | mehamn
# Processing Record 22 of Set 13 | prince rupert
# Processing Record 23 of Set 13 | oksfjord
# Processing Record 24 of Set 13 | belushya guba
# City not found. Skipping...
# Processing Record 25 of Set 13 | young
# Processing Record 26 of Set 13 | carahue
# Processing Record 27 of Set 13 | faya
# Processing Record 28 of Set 13 | baran
# Processing Record 29 of Set 13 | haifa
# Processing Record 30 of Set 13 | athabasca
# Processing Record 31 of Set 13 | corowa
# Processing Record 32 of Set 13 | san patricio
# Processing Record 33 of Set 13 | babanusah
# City not found. Skipping...
# Processing Record 34 of Set 13 | bubaque
# Processing Record 35 of Set 13 | zyryanka
# Processing Record 36 of Set 13 | orumiyeh
# Processing Record 37 of Set 13 | pedasi
# Processing Record 38 of Set 13 | cidra
# Processing Record 39 of Set 13 | pekan
# Processing Record 40 of Set 13 | longlac
# City not found. Skipping...
# Processing Record 41 of Set 13 | sumbe
# Processing Record 42 of Set 13 | svetlaya
# Processing Record 43 of Set 13 | straumen
# Processing Record 44 of Set 13 | rio grande city
# Processing Record 45 of Set 13 | isangel
# Processing Record 46 of Set 13 | mecca
# Processing Record 47 of Set 13 | plettenberg bay
# Processing Record 48 of Set 13 | port moresby
# Processing Record 49 of Set 13 | srednekolymsk
# Processing Record 50 of Set 13 | marau
# Processing Record 1 of Set 14 | yarensk
# Processing Record 2 of Set 14 | mpulungu
# Processing Record 3 of Set 14 | port-gentil
# Processing Record 4 of Set 14 | sembakung
# Processing Record 5 of Set 14 | bolungarvik
# City not found. Skipping...
# Processing Record 6 of Set 14 | korla
# Processing Record 7 of Set 14 | port hardy
# Processing Record 8 of Set 14 | udaipur
# Processing Record 9 of Set 14 | raymond
# Processing Record 10 of Set 14 | anuppur
# Processing Record 11 of Set 14 | dourados
# Processing Record 12 of Set 14 | santa rosa
# Processing Record 13 of Set 14 | gizo
# Processing Record 14 of Set 14 | achisay
# City not found. Skipping...
# Processing Record 15 of Set 14 | morehead
# Processing Record 16 of Set 14 | murgab
# Processing Record 17 of Set 14 | cocorit
# Processing Record 18 of Set 14 | vrbas
# Processing Record 19 of Set 14 | nuuk
# Processing Record 20 of Set 14 | ituni
# City not found. Skipping...
# Processing Record 21 of Set 14 | lanxi
# Processing Record 22 of Set 14 | yorkton
# Processing Record 23 of Set 14 | kuche
# City not found. Skipping...
# Processing Record 24 of Set 14 | makokou
# Processing Record 25 of Set 14 | gurlan
# Processing Record 26 of Set 14 | ngozi
# Processing Record 27 of Set 14 | saint-joseph
# Processing Record 28 of Set 14 | blackwater
# Processing Record 29 of Set 14 | waipawa
# Processing Record 30 of Set 14 | sioux lookout
# Processing Record 31 of Set 14 | druzhba
# Processing Record 32 of Set 14 | vao
# Processing Record 33 of Set 14 | peru
# Processing Record 34 of Set 14 | tautira
# Processing Record 35 of Set 14 | martil
# Processing Record 36 of Set 14 | chegdomyn
# Processing Record 37 of Set 14 | goshen
# Processing Record 38 of Set 14 | saint-ambroise
# Processing Record 39 of Set 14 | washington
# Processing Record 40 of Set 14 | husavik
# Processing Record 41 of Set 14 | santa fe
# Processing Record 42 of Set 14 | atocha
# Processing Record 43 of Set 14 | ust-kuyga
# Processing Record 44 of Set 14 | baishishan
# Processing Record 45 of Set 14 | salinopolis
# Processing Record 46 of Set 14 | utete
# Processing Record 47 of Set 14 | plastun
# Processing Record 48 of Set 14 | katsiveli
# City not found. Skipping...
# Processing Record 49 of Set 14 | shahr-e kord
# Processing Record 50 of Set 14 | liuzhou
# Processing Record 1 of Set 15 | rohnert park
# Processing Record 2 of Set 15 | rundu
# Processing Record 3 of Set 15 | mutsamudu
# City not found. Skipping...
# Processing Record 4 of Set 15 | shcholkine
# City not found. Skipping...
# Processing Record 5 of Set 15 | makakilo city
# Processing Record 6 of Set 15 | varhaug
# Processing Record 7 of Set 15 | honiara
# Processing Record 8 of Set 15 | pindiga
# Processing Record 9 of Set 15 | bonthe
# Processing Record 10 of Set 15 | biak
# Processing Record 11 of Set 15 | bur gabo
# City not found. Skipping...
# Processing Record 12 of Set 15 | santa luzia
# Processing Record 13 of Set 15 | bouna
# Processing Record 14 of Set 15 | plopii slavitesti
# Processing Record 15 of Set 15 | blacksburg
# Processing Record 16 of Set 15 | antalaha
# Processing Record 17 of Set 15 | haines junction
# Processing Record 18 of Set 15 | richmond
# Processing Record 19 of Set 15 | virginia beach
# Processing Record 20 of Set 15 | westport
# Processing Record 21 of Set 15 | kralendijk
# Processing Record 22 of Set 15 | ayagoz
# Processing Record 23 of Set 15 | ngaoundere
# Processing Record 24 of Set 15 | muisne
# Processing Record 25 of Set 15 | tiznit
# Processing Record 26 of Set 15 | kembaran
# Processing Record 27 of Set 15 | sambava
# Processing Record 28 of Set 15 | gariaband
# Processing Record 29 of Set 15 | maghama
# City not found. Skipping...
# Processing Record 30 of Set 15 | yanan
# City not found. Skipping...
# Processing Record 31 of Set 15 | puerto escondido
# Processing Record 32 of Set 15 | saurimo
# Processing Record 33 of Set 15 | farmington
# Processing Record 34 of Set 15 | tambura
# Processing Record 35 of Set 15 | broken hill
# Processing Record 36 of Set 15 | san fernando
# Processing Record 37 of Set 15 | trinitapoli
# Processing Record 38 of Set 15 | chagda
# City not found. Skipping...
# Processing Record 39 of Set 15 | salinas
# Processing Record 40 of Set 15 | fengcheng
# Processing Record 41 of Set 15 | les cayes
# Processing Record 42 of Set 15 | zarya
# Processing Record 43 of Set 15 | burnie
# Processing Record 44 of Set 15 | north battleford
# Processing Record 45 of Set 15 | severomuysk
# Processing Record 46 of Set 15 | umarkot
# Processing Record 47 of Set 15 | gujan-mestras
# Processing Record 48 of Set 15 | maputo
# Processing Record 49 of Set 15 | kurtalan
# Processing Record 50 of Set 15 | uwayl
# City not found. Skipping...
# Processing Record 1 of Set 16 | benxi
# Processing Record 2 of Set 16 | sa kaeo
# Processing Record 3 of Set 16 | harwich
# Processing Record 4 of Set 16 | vila franca do campo
# Processing Record 5 of Set 16 | riohacha
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 688

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#               City      Lat       Lng  Max Temp      Current Description  \
# 0  Bambous Virieux -20.3428   57.7575     72.21               light rain
# 1         Karratha -20.7377  116.8463     78.10                clear sky
# 2     Ponta Do Sol  32.6667  -17.1000     73.00            broken clouds
# 3        Taoudenni  22.6783   -3.9836     83.16          overcast clouds
# 4            Pisco -13.7000  -76.2167     62.65                clear sky
# 5    Mar Del Plata -38.0023  -57.5575     54.09               light rain
# 6           Graham  47.0529 -122.2943     48.36  light intensity drizzle
# 7          Repnoye  51.5921   43.1861     39.18          overcast clouds
# 8            Nizwa  22.9333   57.5333     72.01                clear sky
# 9     Punta Arenas -53.1500  -70.9167     48.31                clear sky
#
#    Humidity  Cloudiness  Wind Speed Country                 Date
# 0        88          40        5.75      MU  2022-10-21 23:52:08
# 1        44           0       15.14      AU  2022-10-21 23:52:09
# 2        84          76        5.08      PT  2022-10-21 23:51:03
# 3        13         100       14.38      ML  2022-10-21 23:52:10
# 4        77           0       13.80      PE  2022-10-21 23:52:10
# 5        84          75       18.41      AR  2022-10-21 23:49:31
# 6        91          20        6.91      US  2022-10-21 23:52:11
# 7        69          89        7.29      RU  2022-10-21 23:52:11
# 8        26           0        1.72      OM  2022-10-21 23:52:12
# 9        46           0       32.21      CL  2022-10-21 23:48:45

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Current Description', 'Humidity',
#        'Cloudiness', 'Wind Speed', 'Country', 'Date'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
city_data_df = city_data_df[['City', 'Country', 'Lat', 'Lng',
                            'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed', 'Current Description']]

# Recreate the DataFrame by using the new column order
# YOUR CODE HERE

# Display sample data
city_data_df.head()
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Bambous Virieux      MU -20.3428   57.7575     72.21        88          40
# 1         Karratha      AU -20.7377  116.8463     78.10        44           0
# 2     Ponta Do Sol      PT  32.6667  -17.1000     73.00        84          76
# 3        Taoudenni      ML  22.6783   -3.9836     83.16        13         100
# 4            Pisco      PE -13.7000  -76.2167     62.65        77           0
#
#    Wind Speed Current Description
# 0        5.75          light rain
# 1       15.14           clear sky
# 2        5.08       broken clouds
# 3       14.38     overcast clouds
# 4       13.80           clear sky

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
